# %% [markdown]
# # Imports

# %%
import sys
sys.path.append("/Users/will/Desktop/WeitzLab/melt/code/")
import utils
import importlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import pairwise_distances

# %% [markdown]
# ## Confused by the parameter names? Try *help(utils.function_name)*
#
# **Example**

# %%
help(utils.plot_keypoint_tracking)
# Out:
# Help on function plot_keypoint_tracking in module utils:
#
# plot_keypoint_tracking(image_array: numpy.ndarray, pts_seq: numpy.ndarray, keypoint_index: int, m: int, alignment_correction: bool = None, save_video: bool = False, video_filename: str = 'tracking.mp4', radius=8)
#     Visualizes the key point tracking before and after alignment with circles around the actual keypoints.
#     Optionally saves the entire series as an mp4 video.
#
#     Args:
#     - image_array (np.array): The image array of shape (N, M, M), where N is the nunber of frames and M is the image width/height
#     - pts_seq (np.array): The key points sequence of shape (K, N, 2), where K is the number of key center points, N is the number of frames, and 2 is the x-y coordinates
#     - keypoint_index (int): The index of the key point to visualize.
#     - m (int): Size of the zoom area (m x m).
#     - alignment_correction (np.array or None): The corrected positions of key points, same shape as pts_seq.
# ...

# %% [markdown]
# # Load saved files

# %%
global_tm = ["LowTm", "HighTm"]

# %% [markdown]
# ## Load Predicted Tm data

# %%
pred_c1 = pd.read_csv("../../pred_Tm_raw/B1R1.csv")
pred_c2 = pd.read_csv("../../pred_Tm_raw/B1G1.csv")
pred_c3 = pd.read_csv("../../pred_Tm_raw/G1R1.csv")
pred_c4 = pd.read_csv("../../pred_Tm_raw/R1G1.csv")

# %% [markdown]
# # Load Alignment Area

# %% [markdown]
# ### Note:
# * Probe Combo 1 = B1R1
# * Probe Combo 2 = B1G1
# * Probe Combo 3 = G1R1
# * Probe Combo 4 = R1G1

# %% [markdown]
# ## Area 1

# %%
par_dir = ""

# %%
a1_c1 = pd.read_csv(par_dir+"chip1-1_B1R1_bkg_subtracted.csv") # Probe Combo 1
a1_c2 = pd.read_csv(par_dir+"chip1-1_B1G1_bkg_subtracted.csv") # Probe Combo 2
a1_c3 = pd.read_csv(par_dir+"chip1-1_G1R1_bkg_subtracted.csv") # Probe Combo 3
a1_c4 = pd.read_csv(par_dir+"chip1-1_R1G1_bkg_subtracted.csv") # Probe Combo 4

# %% [markdown]
# ## Area 2

# %%
a2_c1 = pd.read_csv(par_dir+"chip1-2_B1R1_bkg_subtracted.csv") # Probe Combo 1
a2_c2 = pd.read_csv(par_dir+"chip1-2_B1G1_bkg_subtracted.csv") # Probe Combo 2
a2_c3 = pd.read_csv(par_dir+"chip1-2_G1R1_bkg_subtracted.csv") # Probe Combo 3
a2_c4 = pd.read_csv(par_dir+"chip1-2_R1G1_bkg_subtracted.csv") # Probe Combo 4

# %% [markdown]
# ## Area 3

# %%
a3_c1 = pd.read_csv(par_dir+"chip1-3_B1R1_bkg_subtracted.csv") # Probe Combo 1
a3_c2 = pd.read_csv(par_dir+"chip1-3_B1G1_bkg_subtracted.csv") # Probe Combo 2
a3_c3 = pd.read_csv(par_dir+"chip1-3_G1R1_bkg_subtracted.csv") # Probe Combo 3
a3_c4 = pd.read_csv(par_dir+"chip1-3_R1G1_bkg_subtracted.csv") # Probe Combo 4

# %% [markdown]
# ## Area 4

# %%
a4_c1 = pd.read_csv(par_dir+"chip2_1_B1R1_bkg_subtracted.csv") # Probe Combo 1
a4_c2 = pd.read_csv(par_dir+"chip2_1_B1G1_bkg_subtracted.csv") # Probe Combo 2
a4_c3 = pd.read_csv(par_dir+"chip2_1_G1R1_bkg_subtracted.csv") # Probe Combo 3
a4_c4 = pd.read_csv(par_dir+"chip2_1_R1G1_bkg_subtracted.csv") # Probe Combo 4

# %% [markdown]
# ## Area 5

# %%
a5_c1 = pd.read_csv(par_dir+"chip2_2_B1R1_bkg_subtracted.csv") # Probe Combo 1
a5_c2 = pd.read_csv(par_dir+"chip2_2_B1G1_bkg_subtracted.csv") # Probe Combo 2
a5_c3 = pd.read_csv(par_dir+"chip2_2_G1R1_bkg_subtracted.csv") # Probe Combo 3
a5_c4 = pd.read_csv(par_dir+"chip2_2_R1G1_bkg_subtracted.csv") # Probe Combo 4

# %% [markdown]
# ## Area 6

# %%
a6_c1 = pd.read_csv(par_dir+"chip3-1_B1R1_bkg_subtracted.csv") # Probe Combo 1
a6_c2 = pd.read_csv(par_dir+"chip3-1_B1G1_bkg_subtracted.csv") # Probe Combo 2
a6_c3 = pd.read_csv(par_dir+"chip3-1_G1R1_bkg_subtracted.csv") # Probe Combo 3
a6_c4 = pd.read_csv(par_dir+"chip3-1_R1G1_bkg_subtracted.csv") # Probe Combo 4

# %% [markdown]
# # Area 7

# %%
a7_c1 = pd.read_csv(par_dir+"chip3-2_B1R1_bkg_subtracted.csv") # Probe Combo 1
a7_c2 = pd.read_csv(par_dir+"chip3-2_B1G1_bkg_subtracted.csv") # Probe Combo 2
a7_c3 = pd.read_csv(par_dir+"chip3-2_G1R1_bkg_subtracted.csv") # Probe Combo 3
a7_c4 = pd.read_csv(par_dir+"chip3-2_R1G1_bkg_subtracted.csv") # Probe Combo 4

# %% [markdown]
# # Probe Combo 1

# %%
aligned_c1, c1_shift = utils.align_datasets(data1 = a1_c1, data2 = [a2_c1, a3_c1,
                                                                         a4_c1, a5_c1, a6_c1, a7_c1], 
                                     size=120, max_shift_x=2, max_shift_y=2, 
                                    cols_to_align=['LowTm', 'HighTm'], manual=True)

# %%
pred_c1_transformed, pred_shift = utils.align_datasets(data1 = a1_c1, data2 = pred_c1,
                                     size=120, max_shift_x=1, max_shift_y=1, 
                                    cols_to_align=['LowTm', 'HighTm'], manual=True)

# %%
pred_c1_transformed = utils.apply_global_shift(pred_c1, shift=pred_shift[0], cols_to_shift=["LowTm", "HighTm"])

# %% [markdown]
# ## Normalization-Align Across Chips and Prediction

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/will/Desktop/WeitzLab/melt/code/utils.py'>

# %%
aligned_a2_c1 = utils.apply_global_shift(aligned_c1[0], shift=c1_shift[0], cols_to_shift=["LowTm", "HighTm"])
aligned_a3_c1 = utils.apply_global_shift(aligned_c1[1], shift=c1_shift[1], cols_to_shift=["LowTm", "HighTm"])
aligned_a4_c1 = utils.apply_global_shift(aligned_c1[2], shift=c1_shift[2], cols_to_shift=["LowTm", "HighTm"])
aligned_a5_c1 = utils.apply_global_shift(aligned_c1[3], shift=c1_shift[3], cols_to_shift=["LowTm", "HighTm"])
aligned_a6_c1 = utils.apply_global_shift(aligned_c1[4], shift=c1_shift[4], cols_to_shift=["LowTm", "HighTm"])
aligned_a7_c1 = utils.apply_global_shift(aligned_c1[5], shift=c1_shift[5], cols_to_shift=["LowTm", "HighTm"])
# Out:
# The amount of shift applied to the data is: [0. 0.]
# The amount of shift applied to the data is: [-0.02 -0.19]
# The amount of shift applied to the data is: [-0.87 -1.08]
# The amount of shift applied to the data is: [-1.58 -1.24]
# The amount of shift applied to the data is: [-0.51 -0.58]
# The amount of shift applied to the data is: [-0.52 -0.6 ]

# %%
c1_nline_x = 3
c1_nline_y = 8
pred_c1_grid = utils.create_grid(pred_c1[global_tm], c1_nline_x, c1_nline_y)

# %%
all_c1 = np.vstack([a1_c1[global_tm],
                    aligned_a2_c1[global_tm], 
                    aligned_a3_c1[global_tm],
                    aligned_a4_c1[global_tm], 
                    aligned_a5_c1[global_tm],
                    aligned_a6_c1[global_tm],
                   aligned_a7_c1[global_tm],
                   ])

# %%
all_c1_grid = utils.create_grid(all_c1, c1_nline_x, c1_nline_y,manual= False)

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/will/Desktop/WeitzLab/melt/code/utils.py'>

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/will/Desktop/WeitzLab/melt/code/utils.py'>

# %%
mapping_dir = "../../baseline_mapping/"

# %%
c1_transform_fns, pred_c1_transformed = utils.grid_transform(pred_c1_grid, 
                                                           data_to_transform=pred_c1,
                                                            f_u_load_dirs = [mapping_dir+"B1R1/B1R1_1_f_u.pkl", mapping_dir+"B1R1/B1R1_2_f_u.pkl"],
                                                            f_v_load_dirs = [mapping_dir+"B1R1/B1R1_1_f_v.pkl", mapping_dir+"B1R1/B1R1_2_f_v.pkl"]
                                                        )

# %%
utils.scatter_plot_dfs([pred_c1_transformed, a1_c1, 
                        aligned_a2_c1,aligned_a3_c1,
                        aligned_a4_c1,aligned_a5_c1,
                        aligned_a6_c1, aligned_a7_c1
                       ], "LowTm", "HighTm")

# %%
utils.scatter_plot_dfs([pred_c1_transformed, a1_c1, 
                        aligned_a2_c1,aligned_a3_c1,
                        aligned_a4_c1,aligned_a5_c1,
                        aligned_a6_c1, aligned_a7_c1
                       ], "LowTm", "HighTm")

# %%
_, pred_c1_shift = utils.align_datasets(data1 = a1_c1, data2 = pred_c1_transformed,
                                     size=120, max_shift_x=2, max_shift_y=2, 
                                    cols_to_align=['LowTm', 'HighTm'], manual=True)
# Out:
# === Alignment for Dataset 1 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D1)', layout=Layout(width='1000px'), max=2.…

# %%
pred_c1_transformed = utils.apply_global_shift(pred_c1_transformed, shift=pred_c1_shift[0], cols_to_shift=["LowTm", "HighTm"])
# Out:
# The amount of shift applied to the data is: [1.28 0.56]

# %%
utils.scatter_plot_dfs([pred_c1_transformed, a1_c1, 
                        aligned_a2_c1,aligned_a3_c1,
                        aligned_a4_c1,
                       ], "LowTm", "HighTm")

# %% [markdown]
# ## Matching with Prediction

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/will/Desktop/WeitzLab/melt/code/utils.py'>

# %%
concatenated_c1 = utils.process_df_list([a1_c1, aligned_a2_c1, aligned_a3_c1, 
                                       aligned_a4_c1, aligned_a5_c1,
                        aligned_a6_c1, aligned_a7_c1
                                        ])

# %%
c1_dist_mat = pairwise_distances(concatenated_c1[["LowTm", "HighTm"]], pred_c1_transformed[["LowTm", "HighTm"]])
concatenated_c1_idx_list = concatenated_c1.index.tolist()
c1_gene_names = pred_c1_transformed["gene_name"].tolist()

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/will/Desktop/WeitzLab/melt/code/utils.py'>

# %%
c1_dist_matL, c1_dist_matH = utils.compute_distance_matrix(concatenated_c1[["LowTm", "HighTm"]], pred_c1_transformed[["LowTm", "HighTm"]])

# %%
pred_c1_transformed = pred_c1_transformed[pred_c1_transformed.gene_name != "B1R1-NCAM1"]

# %%
c1_dist_mat = pairwise_distances(concatenated_c1[["LowTm", "HighTm"]], pred_c1_transformed[["LowTm", "HighTm"]])
concatenated_c1_idx_list = concatenated_c1.index.tolist()
c1_gene_names = pred_c1_transformed["gene_name"].tolist()

# %%
utils.scatter_plot_dfs([pred_c1_transformed, a1_c1, 
                        aligned_a2_c1,aligned_a3_c1,
                        aligned_a4_c1
                       ], "LowTm", "HighTm")

# %%
c1_matching = utils.greedy_surjective_constrained_matching(concatenated_c1_idx_list, c1_gene_names, c1_dist_mat, 1.2)

# %%
utils.plot_matching(c1_matching, concatenated_c1, ["LowTm","HighTm"])

# %% [markdown]
# ## Probablistic Cluster Refinement

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/will/Desktop/WeitzLab/melt/code/utils.py'>

# %%
new_matching_df_c1, _ = utils.refine_clusters(matching_df=c1_matching, external_df= concatenated_c1, 
                                  selected_column_names = ["LowTm","HighTm"], model="GMM")

# %%
utils.plot_matching(new_matching_df_c1, concatenated_c1, ["LowTm","HighTm"])

# %%
concatenated_c1
# Out:
#                 Unnamed: 0  Pos X  Pos Y  Cy5 Tm 1  Cy5 Tm 2  DsRed-hex Tm 1  \
# Area_ID Row_ID
# 0       1                1     18     69     79.00       0.0             0.0
#         5                5     30    590     79.00       0.0             0.0
#         7                7     31    548     79.00       0.0             0.0
#         10              10     34    250     79.00       0.0             0.0
#         11              11     34    313     79.00       0.0             0.0
# ...                    ...    ...    ...       ...       ...             ...
# 6       701            701   1172    417     78.67       0.0             0.0
#         704            704   1176    152     78.67       0.0             0.0
#         707            707   1179    215     78.67       0.0             0.0
#         709            709   1180    915     78.67       0.0             0.0
#         718            718   1016    913     78.67       0.0             0.0
#
# ...

# %%
pc_result1 = utils.plot_matching_interactive(matching_df=new_matching_df_c1, external_df=concatenated_c1, 
                                   selected_column_names=["LowTm", "HighTm"],
                                   std_x=0.5, std_y=0.25, off_diag=0)
# Out:
# Plotting interactive matching visualisation...
# ...

# %%
pc1_stats = pc_result1["stats_df"]

# %% [markdown]
# # Probe Combo 2

# %%
aligned_c2, c2_shift = utils.align_datasets(data1 = a1_c2, data2 = [a2_c2, a3_c2,
                                                                         a4_c2, a5_c2, a6_c2, a7_c2 ], 
                                     size=120, max_shift_x=2, max_shift_y=2, 
                                    cols_to_align=['LowTm', 'HighTm'], manual=True)
# Out:
# === Alignment for Dataset 1 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D1)', layout=Layout(width='1000px'), max=2.…
# === Alignment for Dataset 2 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D2)', layout=Layout(width='1000px'), max=2.…
# === Alignment for Dataset 3 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D3)', layout=Layout(width='1000px'), max=2.…
# === Alignment for Dataset 4 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D4)', layout=Layout(width='1000px'), max=2.…
# === Alignment for Dataset 5 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D5)', layout=Layout(width='1000px'), max=2.…
# === Alignment for Dataset 6 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D6)', layout=Layout(width='1000px'), max=2.…

# %% [markdown]
# ## Normalization-Align Across Chips and Prediction

# %%
aligned_a2_c2 = utils.apply_global_shift(aligned_c2[0], shift=c2_shift[0], cols_to_shift=["LowTm", "HighTm"])
aligned_a3_c2 = utils.apply_global_shift(aligned_c2[1], shift=c2_shift[1], cols_to_shift=["LowTm", "HighTm"])
aligned_a4_c2 = utils.apply_global_shift(aligned_c2[2], shift=c2_shift[2], cols_to_shift=["LowTm", "HighTm"])
aligned_a5_c2 = utils.apply_global_shift(aligned_c2[3], shift=c2_shift[3], cols_to_shift=["LowTm", "HighTm"])
aligned_a6_c2 = utils.apply_global_shift(aligned_c2[4], shift=c2_shift[4], cols_to_shift=["LowTm", "HighTm"])
aligned_a7_c2 = utils.apply_global_shift(aligned_c2[5], shift=c2_shift[5], cols_to_shift=["LowTm", "HighTm"])
# Out:
# The amount of shift applied to the data is: [0. 0.]
# The amount of shift applied to the data is: [-0.16 -0.17]
# The amount of shift applied to the data is: [-1.04 -0.88]
# The amount of shift applied to the data is: [-1.29 -0.82]
# The amount of shift applied to the data is: [-0.15 -0.36]
# The amount of shift applied to the data is: [-0.28 -0.3 ]

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/will/Desktop/WeitzLab/melt/code/utils.py'>

# %%
c2_nline_x = 4
c2_nline_y = 9
pred_c2_grid = utils.create_grid(pred_c2[global_tm], c2_nline_x, c2_nline_y, x_range=None)

# %%
c2_transform_fns, pred_c2_transformed = utils.grid_transform(pred_c2_grid, 
                                                           data_to_transform=pred_c2,
                                                            f_u_load_dirs = [mapping_dir+"B1G1/B1G1_f_u_1.pkl", mapping_dir+"B1G1/B1G1_f_u_2.pkl"],
                                                            f_v_load_dirs = [mapping_dir+"B1G1/B1G1_f_v_1.pkl", mapping_dir+"B1G1/B1G1_f_v_2.pkl"]
                                                        )

# %%
utils.scatter_plot_dfs([pred_c2, a1_c2, 
                        aligned_a2_c2,aligned_a3_c2,
                        aligned_a4_c2, 
                        aligned_a5_c2, aligned_a6_c2, aligned_a7_c2
                       ], "LowTm", "HighTm")

# %%
_, pred_c2_shift = utils.align_datasets(data1 = a1_c2, data2 = pred_c2_transformed,
                                     size=120, max_shift_x=3, max_shift_y=3, 
                                    cols_to_align=['LowTm', 'HighTm'], manual=True)
# Out:
# === Alignment for Dataset 1 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D1)', layout=Layout(width='1000px'), max=3.…

# %%
pred_c2_transformed = utils.apply_global_shift(pred_c2_transformed, shift=pred_c2_shift[0], cols_to_shift=["LowTm", "HighTm"])
# Out:
# The amount of shift applied to the data is: [1.67 0.06]

# %%
utils.scatter_plot_dfs([pred_c2_transformed, a1_c2, 
                        aligned_a2_c2,aligned_a3_c2,
                        aligned_a4_c2,
                       ], "LowTm", "HighTm")

# %% [markdown]
# ## Matching with Prediction

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/will/Desktop/WeitzLab/melt/code/utils.py'>

# %%
concatenated_c2 = utils.process_df_list([a1_c2, aligned_a2_c2, aligned_a3_c2, 
                                       aligned_a4_c2, aligned_a5_c2, aligned_a6_c2, aligned_a7_c2])

# %%
utils.scatter_plot_dfs([pred_c2_transformed, a1_c2, 
                        aligned_a2_c2,aligned_a3_c2,
                        aligned_a4_c2
                       ], "LowTm", "HighTm")

# %%
c2_dist_mat = pairwise_distances(concatenated_c2[["LowTm", "HighTm"]], pred_c2_transformed[["LowTm", "HighTm"]])
concatenated_c2_idx_list = concatenated_c2.index.tolist()
c2_gene_names = pred_c2["gene_name"].tolist()

# %%
c2_matching = utils.greedy_surjective_constrained_matching(concatenated_c2_idx_list, c2_gene_names, c2_dist_mat, 1.)

# %%
utils.plot_matching(c2_matching, concatenated_c2, ["LowTm","HighTm"])

# %% [markdown]
# ## Probablistic Cluster Refinement

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/will/Desktop/WeitzLab/melt/code/utils.py'>

# %%
new_matching_df_c2, _ = utils.refine_clusters(matching_df=c2_matching, external_df= concatenated_c2, 
                                  selected_column_names = ["LowTm","HighTm"], model="KMeans")

# %%
utils.plot_matching(new_matching_df_c2, concatenated_c2, ["LowTm","HighTm"])

# %%
pc_result2 = utils.plot_matching_interactive(matching_df=new_matching_df_c2, external_df=concatenated_c2, 
                                   selected_column_names=["LowTm", "HighTm"],
                                   std_x=0.5, std_y=0.25, off_diag=0)
# Out:
# Plotting interactive matching visualisation...
# ...

# %%
pc2_stats = pc_result2["stats_df"]

# %% [markdown]
# # Probe Combo 3

# %%
aligned_c3, c3_shift = utils.align_datasets(data1 = a1_c3, data2 = [a2_c3, a3_c3,
                                                                         a4_c3, 
                                                                   a5_c3, a6_c3, a7_c3], 
                                     size=120, max_shift_x=2, max_shift_y=2, 
                                    cols_to_align=['LowTm', 'HighTm'], manual=True)
# Out:
# === Alignment for Dataset 1 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D1)', layout=Layout(width='1000px'), max=2.…
# === Alignment for Dataset 2 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D2)', layout=Layout(width='1000px'), max=2.…
# === Alignment for Dataset 3 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D3)', layout=Layout(width='1000px'), max=2.…
# === Alignment for Dataset 4 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D4)', layout=Layout(width='1000px'), max=2.…
# === Alignment for Dataset 5 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D5)', layout=Layout(width='1000px'), max=2.…
# === Alignment for Dataset 6 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D6)', layout=Layout(width='1000px'), max=2.…

# %% [markdown]
# ## Normalization-Align Across Chips and Prediction

# %%
c3_nline_x = 7
c3_nline_y = 9
pred_c3_grid = utils.create_grid(pred_c3[global_tm], c3_nline_x, c3_nline_y)

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/will/Desktop/WeitzLab/melt/code/utils.py'>

# %%
aligned_a2_c3 = utils.apply_global_shift(aligned_c3[0], shift=c3_shift[0], cols_to_shift=["LowTm", "HighTm"])
aligned_a3_c3 = utils.apply_global_shift(aligned_c3[1], shift=c3_shift[1], cols_to_shift=["LowTm", "HighTm"])
aligned_a4_c3 = utils.apply_global_shift(aligned_c3[2], shift=c3_shift[2], cols_to_shift=["LowTm", "HighTm"])
aligned_a5_c3 = utils.apply_global_shift(aligned_c3[3], shift=c3_shift[3], cols_to_shift=["LowTm", "HighTm"])
aligned_a6_c3 = utils.apply_global_shift(aligned_c3[4], shift=c3_shift[4], cols_to_shift=["LowTm", "HighTm"])
aligned_a7_c3 = utils.apply_global_shift(aligned_c3[5], shift=c3_shift[5], cols_to_shift=["LowTm", "HighTm"])
# Out:
# The amount of shift applied to the data is: [0. 0.]
# The amount of shift applied to the data is: [-0.21 -0.31]
# The amount of shift applied to the data is: [-0.98 -0.98]
# The amount of shift applied to the data is: [-1.16 -1.05]
# The amount of shift applied to the data is: [-0.18 -0.45]
# The amount of shift applied to the data is: [-0.17 -0.49]

# %%
c3_transform_fns, pred_c3_transformed = utils.grid_transform(pred_c3_grid, 
                                                           data_to_transform=pred_c3,
                                                            f_u_load_dirs = [mapping_dir+"G1R1/G1R1_f_u_1.pkl", mapping_dir+"G1R1/G1R1_f_u_2.pkl"],
                                                            f_v_load_dirs = [mapping_dir+"G1R1/G1R1_f_v_1.pkl", mapping_dir+"G1R1/G1R1_f_v_2.pkl"]
                                                        )

# %%
utils.scatter_plot_dfs([pred_c3_transformed, a1_c3, 
                        aligned_a2_c3,aligned_a3_c3,
                        aligned_a4_c3, aligned_a5_c3,
                        aligned_a6_c3, aligned_a7_c3
                       ], "LowTm", "HighTm")

# %%
_, pred_c3_shift = utils.align_datasets(data1 = a1_c3, data2 = pred_c3_transformed,
                                     size=120, max_shift_x=1, max_shift_y=1, 
                                    cols_to_align=['LowTm', 'HighTm'], manual=True)
# Out:
# === Alignment for Dataset 1 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D1)', layout=Layout(width='1000px'), max=1.…

# %%
pred_c3_transformed = utils.apply_global_shift(pred_c3_transformed, shift=pred_c3_shift[0], cols_to_shift=["LowTm", "HighTm"])
# Out:
# The amount of shift applied to the data is: [0.7  0.92]

# %%
utils.scatter_plot_dfs([pred_c3_transformed, a1_c3, 
                        aligned_a2_c3,aligned_a3_c3,
                        aligned_a4_c3, aligned_a5_c3,
                        aligned_a6_c3, aligned_a7_c3], "LowTm", "HighTm")

# %% [markdown]
# ## Matching with Predictions

# %%
concatenated_c3 = utils.process_df_list([a1_c3, aligned_a2_c3, aligned_a3_c3, 
                                       aligned_a4_c3, 
                                         aligned_a5_c3,
                        aligned_a6_c3, aligned_a7_c3
                                        ])

# %%
c3_dist_mat = pairwise_distances(concatenated_c3[["LowTm", "HighTm"]], pred_c3_transformed[["LowTm", "HighTm"]])
concatenated_c3_idx_list = concatenated_c3.index.tolist()
c3_gene_names = pred_c3["gene_name"].tolist()

# %%
utils.scatter_plot_dfs([pred_c3_transformed, a1_c3, 
                        aligned_a2_c3,aligned_a3_c3,
                        aligned_a4_c3,], "LowTm", "HighTm")

# %%
c3_matching = utils.greedy_surjective_constrained_matching(concatenated_c3_idx_list, c3_gene_names, c3_dist_mat, 1)

# %%
utils.plot_matching(c3_matching, concatenated_c3, ["LowTm","HighTm"])

# %% [markdown]
# ## Probablistic Cluster Refinement

# %%
new_matching_df_c3, _ = utils.refine_clusters(matching_df=c3_matching, external_df= concatenated_c3, 
                                  selected_column_names = ["LowTm","HighTm"], model = "KMeans")

# %%
utils.plot_matching(new_matching_df_c3, concatenated_c3, ["LowTm","HighTm"])

# %%
pc_result3 = utils.plot_matching_interactive(matching_df=c3_matching, external_df=concatenated_c3, 
                                   selected_column_names=["LowTm", "HighTm"],
                                   std_x=0.5, std_y=0.25, off_diag=0)
# Out:
# Plotting interactive matching visualisation...
# ...

# %%
pc3_stats = pc_result3["stats_df"]

# %% [markdown]
# # Probe Combo 4

# %%
aligned_c4, c4_shift = utils.align_datasets(data1 = a1_c4, data2 = [a2_c4, a3_c4,
                                                                         a4_c4,
                                                                   a5_c4, a6_c4, a7_c4], 
                                     size=120, max_shift_x=3, max_shift_y=3, 
                                    cols_to_align=['LowTm', 'HighTm'], manual=True)
# Out:
# === Alignment for Dataset 1 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D1)', layout=Layout(width='1000px'), max=3.…
# === Alignment for Dataset 2 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D2)', layout=Layout(width='1000px'), max=3.…
# === Alignment for Dataset 3 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D3)', layout=Layout(width='1000px'), max=3.…
# === Alignment for Dataset 4 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D4)', layout=Layout(width='1000px'), max=3.…
# === Alignment for Dataset 5 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D5)', layout=Layout(width='1000px'), max=3.…
# === Alignment for Dataset 6 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D6)', layout=Layout(width='1000px'), max=3.…

# %% [markdown]
# ## Normalization-Align Across Chips and Prediction

# %%
c4_nline_x = 7
c4_nline_y = 9
pred_c4_grid = utils.create_grid(pred_c4[global_tm], c4_nline_x, c4_nline_y)

# %%
aligned_a2_c4 = utils.apply_global_shift(aligned_c4[0], shift=c4_shift[0], cols_to_shift=["LowTm", "HighTm"])
aligned_a3_c4 = utils.apply_global_shift(aligned_c4[1], shift=c4_shift[1], cols_to_shift=["LowTm", "HighTm"])
aligned_a4_c4 = utils.apply_global_shift(aligned_c4[2], shift=c4_shift[2], cols_to_shift=["LowTm", "HighTm"])

aligned_a5_c4 = utils.apply_global_shift(aligned_c4[3], shift=c4_shift[3], cols_to_shift=["LowTm", "HighTm"])
aligned_a6_c4 = utils.apply_global_shift(aligned_c4[4], shift=c4_shift[4], cols_to_shift=["LowTm", "HighTm"])
aligned_a7_c4 = utils.apply_global_shift(aligned_c4[5], shift=c4_shift[5], cols_to_shift=["LowTm", "HighTm"])
# Out:
# The amount of shift applied to the data is: [-0.08  0.  ]
# The amount of shift applied to the data is: [ 0.   -0.15]
# The amount of shift applied to the data is: [-2.41 -2.26]
# The amount of shift applied to the data is: [-1.16 -1.2 ]
# The amount of shift applied to the data is: [-0.18 -0.46]
# The amount of shift applied to the data is: [-0.16 -0.48]

# %%
c4_transform_fns, pred_c4_transformed = utils.grid_transform(pred_c4_grid, 
                                                           data_to_transform=pred_c4,
                                                            f_u_load_dirs = [mapping_dir+"R1G1/R1G1_f_u_1.pkl", mapping_dir+"R1G1/R1G1_f_u_2.pkl"],
                                                            f_v_load_dirs = [mapping_dir+"R1G1/R1G1_f_v_1.pkl", mapping_dir+"R1G1/R1G1_f_v_2.pkl"]
                                                        )

# %%
utils.scatter_plot_dfs([pred_c4_transformed, a1_c4, 
                        aligned_a2_c4,aligned_a3_c4,
                        aligned_a4_c4,aligned_a5_c4,
                        aligned_a6_c4,
                        aligned_a7_c4,
                       ], "LowTm", "HighTm")

# %%
_, pred_c4_shift = utils.align_datasets(data1 = a1_c4, data2 = pred_c4_transformed,
                                     size=120, max_shift_x=2, max_shift_y=2, 
                                    cols_to_align=['LowTm', 'HighTm'], manual=True)
# Out:
# === Alignment for Dataset 1 ===
# interactive(children=(FloatSlider(value=0.0, description='Shift X (D1)', layout=Layout(width='1000px'), max=2.…

# %%
pred_c4_transformed = utils.apply_global_shift(pred_c4_transformed, shift=pred_c4_shift[0], cols_to_shift=["LowTm", "HighTm"])
# Out:
# The amount of shift applied to the data is: [1.54 0.29]

# %%
utils.scatter_plot_dfs([pred_c4_transformed, a1_c4, 
                        aligned_a2_c4,aligned_a3_c4,
                        aligned_a4_c4,aligned_a5_c4,
                        aligned_a6_c4,
                        aligned_a7_c4], "LowTm", "HighTm")

# %% [markdown]
# ## Matching with Prediction

# %%
concatenated_c4 = utils.process_df_list([a1_c4, aligned_a2_c4, aligned_a3_c4, 
                                       aligned_a4_c4,aligned_a5_c4,
                        aligned_a6_c4,
                        aligned_a7_c4])

# %%
c4_dist_mat = pairwise_distances(concatenated_c4[["LowTm", "HighTm"]], pred_c4_transformed[["LowTm", "HighTm"]])
concatenated_c4_idx_list = concatenated_c4.index.tolist()
c4_gene_names = pred_c4["gene_name"].tolist()

# %%
utils.scatter_plot_dfs([pred_c4_transformed, a1_c4, 
                        aligned_a2_c4,aligned_a3_c4,
                        aligned_a4_c4,aligned_a5_c4,
                        aligned_a6_c4,
                        aligned_a7_c4], "LowTm", "HighTm")

# %%
c4_matching = utils.greedy_surjective_constrained_matching(concatenated_c4_idx_list, c4_gene_names, c4_dist_mat, 1.5)

# %%
utils.plot_matching(c4_matching, concatenated_c4, ["LowTm","HighTm"])

# %% [markdown]
# ## Probablistic Cluster Refinement

# %%
new_matching_df_c4, _ = utils.refine_clusters(matching_df=c4_matching, external_df= concatenated_c4, 
                                  selected_column_names = ["LowTm","HighTm"], model="KMeans")

# %%
utils.plot_matching(new_matching_df_c4, concatenated_c4, ["LowTm","HighTm"])

# %%
pc_result4 = utils.plot_matching_interactive(matching_df=new_matching_df_c4, external_df=concatenated_c4, 
                                   selected_column_names=["LowTm", "HighTm"],
                                   std_x=0.5, std_y=0.25, off_diag=0)
# Out:
# Plotting interactive matching visualisation...
# ...

# %%
pc4_stats = pc_result4["stats_df"]

# %% [markdown]
# # Visualization

# %%
color_list = ["red", "gold", "orange", "chocolate"]
name_list = ["68.37 R ; Na   ", "Na   ; 77.78 Y", "68.37 R ; 56.55 Y",  "44.36 R ; 77.78 Y"]

# %%
df_list = [pc1_stats, pc2_stats, pc4_stats, pc3_stats]

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/will/Desktop/WeitzLab/melt/code/utils.py'>

# %%
utils.plot_tm_levels(df_list, name_list, color_list, plot_size=(15,100), size_scale=5, z_spacing=30)
# Out:
# Total number of distinct molecules resolved: 35

# %% [markdown]
# # Save results files

# %%
importlib.reload(utils)
# Out:
# <module 'utils' from '/Users/will/Desktop/WeitzLab/melt/code/utils.py'>

# %%
updated_matching_df = pd.concat([pc_result1["updated_matching_df"], pc_result2["updated_matching_df"],
                                pc_result3["updated_matching_df"], pc_result4["updated_matching_df"]], axis=1)
cluster_dict = {}
for col in updated_matching_df.columns:
    for idx_tuple in updated_matching_df[col]:
        if isinstance(idx_tuple, tuple) and len(idx_tuple) == 2:
            idx = int(idx_tuple[1])
            cluster_dict[idx] = col

# %%
updated_all_c1s = utils.update_cluster_assignment(pc_result1["updated_matching_df"], [a1_c1, aligned_a2_c1,
                                                                                     aligned_a3_c1, aligned_a4_c1,
                                                                                     aligned_a5_c1, aligned_a6_c1, aligned_a7_c1
                                                                                     ])
updated_all_c2s = utils.update_cluster_assignment(pc_result2["updated_matching_df"], [a1_c2, aligned_a2_c2,
                                                                                     aligned_a3_c2, aligned_a4_c2,
                                                                                      aligned_a5_c2, aligned_a6_c2, aligned_a7_c2
                                                                                     ])
updated_all_c3s = utils.update_cluster_assignment(pc_result3["updated_matching_df"], [a1_c3, aligned_a2_c3,
                                                                                     aligned_a3_c3, aligned_a4_c3,
                                                                                      aligned_a5_c3, aligned_a6_c3, aligned_a7_c3
                                                                                     ])
updated_all_c4s = utils.update_cluster_assignment(pc_result4["updated_matching_df"], [a1_c4, aligned_a2_c4,
                                                                                     aligned_a3_c4, aligned_a4_c4,
                                                                                      aligned_a5_c4, aligned_a6_c4, aligned_a7_c4
                                                                                     ])

aligned_all_c1 = pd.concat(updated_all_c1s, axis=0)
aligned_all_c2 = pd.concat(updated_all_c2s, axis=0)
aligned_all_c3 = pd.concat(updated_all_c3s, axis=0)
aligned_all_c4 = pd.concat(updated_all_c4s, axis=0)
# Out:
# [update_cluster_assignment]  assigned 485 pairs  |  skipped (bad type): 0  |  skipped (no match / out of bounds): 0
# [update_cluster_assignment]  assigned 350 pairs  |  skipped (bad type): 0  |  skipped (no match / out of bounds): 0
# [update_cluster_assignment]  assigned 570 pairs  |  skipped (bad type): 0  |  skipped (no match / out of bounds): 0
# [update_cluster_assignment]  assigned 47 pairs  |  skipped (bad type): 0  |  skipped (no match / out of bounds): 0

# %%
aligned_all_c1 = aligned_all_c1.reset_index(drop=True)
aligned_all_c2 = aligned_all_c2.reset_index(drop=True)
aligned_all_c3 = aligned_all_c3.reset_index(drop=True)
aligned_all_c4 = aligned_all_c4.reset_index(drop=True)

aligned_all_c1['idx'] = aligned_all_c1.index
aligned_all_c2['idx'] = aligned_all_c2.index
aligned_all_c3['idx'] = aligned_all_c3.index
aligned_all_c4['idx'] = aligned_all_c4.index

aligned_all_c1.to_csv("aligned_all_c1.csv", index=True)
aligned_all_c2.to_csv("aligned_all_c2.csv", index=True)
aligned_all_c3.to_csv("aligned_all_c3.csv", index=True)
aligned_all_c4.to_csv("aligned_all_c4.csv", index=True)

# %%
aligned_all_c1
# Out:
#      Unnamed: 0  Pos X  Pos Y cluster_name  Cy5 Tm 1  Cy5 Tm 2  \
# 0             1     18     69     B1R1-B2M     79.00       0.0
# 1             5     30    590          NaN     79.00       0.0
# 2             7     31    548          NaN     79.00       0.0
# 3            10     34    250     B1R1-B2M     79.00       0.0
# 4            11     34    313          NaN     79.00       0.0
# ..          ...    ...    ...          ...       ...       ...
# 650         701   1172    417     B1R1-B2M     78.67       0.0
# 651         704   1176    152          NaN     78.67       0.0
# 652         707   1179    215   B1R1-TGFB1     78.67       0.0
# 653         709   1180    915   B1R1-TGFB1     78.67       0.0
# 654         718   1016    913          NaN     78.67       0.0
#
#      DsRed-hex Tm 1  DsRed-hex Tm 2      LowTm     HighTm  ...  Intensity 266  \
# 0               0.0             0.0  76.328333  84.763333  ...       0.007181
# ...

# %%
from natsort import natsorted

# Group and count
counts = aligned_all_c2.groupby("cluster_name").size()

# Sort index using natural sorting
counts = counts.loc[natsorted(counts.index)]

# %%
counts
# Out:
# cluster_name
# B1G1-ABR           7
# B1G1-BLR1         16
# B1G1-CD3E         42
# B1G1-CD8A         41
# B1G1-CD14         72
# B1G1-IL2RA         7
# B1G1-LAG3          1
# B1G1-SPP1          1
# B1G1-TNFRSF1B    163
# dtype: int64

# %%
pc1_stats.to_csv("B1R1_stats.csv")
pc2_stats.to_csv("B1G1_stats.csv")
pc3_stats.to_csv("G1R1_stats.csv")
pc4_stats.to_csv("R1G1_stats.csv")

# %%
combined_stats = pd.concat([pc1_stats, pc2_stats, pc3_stats, pc4_stats])
new_names = combined_stats["cluster_name"].to_list()
new_names =[name[5:] for name in new_names]
combined_stats["cluster_name"] =new_names
combined_stats.to_csv("combined_stats.csv")

# %%
combined_stats.shape
# Out:
# (35, 5)

# %%
combined_stats.shape
# Out:
# (35, 5)

# %%
combined_stats = pd.concat([pc1_stats, pc2_stats, pc3_stats, pc4_stats])
new_names = combined_stats["cluster_name"].to_list()
new_names =[name[5:] for name in new_names]
combined_stats["cluster_name"] =new_names

# %%
combined_stats = combined_stats.rename(columns={'cluster_name': 'Cluster_Name', 'counts_by_confidence': 'Num_Points'})

# %%
combined_stats.to_csv("combined_stats.csv", index=False)

# %%
combined_stats = pd.concat([pc1_stats, pc2_stats, pc3_stats, pc4_stats])
new_names = combined_stats["cluster_name"].to_list()
new_names =[name[5:] for name in new_names]
combined_stats["cluster_name"] =new_names

all_lib = pd.read_csv("../../ngs_order.csv")
name_lst = all_lib["gene_name"].to_list()

# %%
combined_stats = combined_stats[combined_stats["cluster_name"].isin(name_lst)]

combined_stats = combined_stats.set_index("cluster_name")

combined_stats = combined_stats.reindex(name_lst).fillna({"counts": 0, "counts_by_confidence": 0})

combined_stats = combined_stats.reset_index().rename(columns={"index": "cluster_name"})
combined_stats["normalized_counts"] = combined_stats["counts"] / combined_stats["counts"].sum()

combined_stats.to_csv("combined_stats_pooled7_sorted.csv", index=False)
